# %% [markdown]
# # Granger causality demo
#
# #### 14th May 2024
#
# cMLP demo from the work of [Tank et. al](https://arxiv.org/abs/1802.05842)

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from synthetic import simulate_var
from models.cmlp import cMLP, cMLPSparse, train_model_ista, train_unregularized, train_model_adam

max_iter_max = 30000
check_every = np.floor(np.sqrt(max_iter_max))

# %%
# For GPU acceleration
device = torch.device('cpu')# torch.device('cuda')

# %% [markdown]
# ## Financial data

# %%
import yfinance as yf
import numpy as np

# Define the symbols
# symbols = ['TTF=F', 'NG=F', 'BAYRY', 'VWAGY', '^GDAXI', 'LNG', 'SHEL', 'EURUSD=X']
symbols = [
    'TTF=F', 
    #'NG=F', 
    'BAYRY', 'VWAGY', 
    '^GDAXI', 'LNG', 
    #'SHEL', 'EURUSD=X',
    #'RUB=X', 'RELIANCE.BO', 
    'BZ=F', 'MTF=F', 
    #'BP', 'TTE', 
    'EONGY', 'RWEOY', 
    'BASFY', 'SIEGY', 'VWDRY'
]
# Fetch data for each symbol
data = {}
for symbol in symbols:
    ticker = yf.Ticker(symbol)
    data[symbol] = ticker.history(period="5y")['Close']

# Ensure all time series have the same length
min_length = min(len(data[symbol]) for symbol in symbols)

# Trim each series to the minimum length
for symbol in symbols:
    data[symbol] = data[symbol][-min_length:]

# Normalize each time series by dividing by its average value
normalized_data = {}
for symbol in symbols:
    avg_value = data[symbol].mean()
    sd = data[symbol].std()
    normalized_data[symbol] = (data[symbol] - avg_value)/sd

# Stack the normalized time series data into a single numpy array
time_series_data = np.array([normalized_data[symbol].values for symbol in symbols])

# Reshape to (1, number_timesteps, number_time_series)
time_series_data2 = time_series_data.T[np.newaxis, :, :]

print(time_series_data.shape)  # Should print (1, min_length, 10)
# Out:
# (19, 1217)

# %%
plt.plot(time_series_data[4])

# %%
X = torch.tensor(time_series_data2, dtype=torch.float32, device=device)
# Plot data
fig, axarr = plt.subplots(1, 2, figsize=(16, 5))
for i in range(time_series_data.shape[0]):
    axarr[0].plot(time_series_data[i])
axarr[0].set_xlabel('T')
axarr[0].set_title('Entire time series')
for i in range(time_series_data.shape[0]):
    axarr[1].plot(time_series_data[i,:50])
axarr[1].set_xlabel('T')
axarr[1].set_title('First 50 time points')
plt.tight_layout()
plt.show()

# %%
cmlp = cMLP(X.shape[-1], lag=5, hidden=[100])#.cuda(device=device)
# Train with ISTA
train_loss_list = train_model_ista(
    cmlp, X, lam=0.002, lam_ridge=1e-2, lr=5e-2, penalty='H', 
    max_iter=max_iter_max,
    check_every=check_every)
# Out:
# ----------Iter = 173----------
# Loss = 0.201330
# Variable usage = 100.00%
# ----------Iter = 346----------
# Loss = 0.186235
# Variable usage = 100.00%
# ----------Iter = 519----------
# Loss = 0.173251
# Variable usage = 100.00%
# ----------Iter = 692----------
# Loss = 0.161160
# Variable usage = 100.00%
# ----------Iter = 865----------
# Loss = 0.149672
# Variable usage = 100.00%
# ----------Iter = 1038----------
# Loss = 0.138694
# Variable usage = 100.00%
# ----------Iter = 1211----------
# Loss = 0.128200
# Variable usage = 100.00%
# ----------Iter = 1384----------
# Loss = 0.118198
# Variable usage = 100.00%
# ----------Iter = 1557----------
# Loss = 0.108715
# Variable usage = 100.00%
# ----------Iter = 1730----------
# Loss = 0.099786
# Variable usage = 100.00%
# ----------Iter = 1903----------
# Loss = 0.091455
# Variable usage = 100.00%
# ----------Iter = 2076----------
# Loss = 0.083780
# Variable usage = 100.00%
# ----------Iter = 2249----------
# Loss = 0.076812
# Variable usage = 100.00%
# ----------Iter = 2422----------
# Loss = 0.070611
# Variable usage = 100.00%
# ----------Iter = 2595----------
# Loss = 0.065238
# Variable usage = 100.00%
# ----------Iter = 2768----------
# Loss = 0.060604
# Variable usage = 100.00%
# ----------Iter = 2941----------
# Loss = 0.056526
# Variable usage = 100.00%
# ----------Iter = 3114----------
# Loss = 0.052977
# Variable usage = 100.00%
# ----------Iter = 3287----------
# Loss = 0.049929
# Variable usage = 100.00%
# ----------Iter = 3460----------
# Loss = 0.047271
# Variable usage = 100.00%
# ----------Iter = 3633----------
# Loss = 0.044910
# Variable usage = 100.00%
# ----------Iter = 3806----------
# Loss = 0.042818
# Variable usage = 100.00%
# ----------Iter = 3979----------
# Loss = 0.040997
# Variable usage = 100.00%
# ----------Iter = 4152----------
# Loss = 0.039417
# Variable usage = 100.00%
# ----------Iter = 4325----------
# Loss = 0.038022
# Variable usage = 100.00%
# ----------Iter = 4498----------
# Loss = 0.036761
# Variable usage = 100.00%
# ----------Iter = 4671----------
# Loss = 0.035610
# Variable usage = 100.00%
# ----------Iter = 4844----------
# Loss = 0.034563
# Variable usage = 100.00%
# ----------Iter = 5017----------
# Loss = 0.033617
# Variable usage = 100.00%
# ----------Iter = 5190----------
# Loss = 0.032775
# Variable usage = 100.00%
# ----------Iter = 5363----------
# Loss = 0.032029
# Variable usage = 100.00%
# ----------Iter = 5536----------
# Loss = 0.031370
# Variable usage = 100.00%
# ----------Iter = 5709----------
# Loss = 0.030788
# Variable usage = 100.00%
# ----------Iter = 5882----------
# Loss = 0.030265
# Variable usage = 100.00%
# ----------Iter = 6055----------
# Loss = 0.029783
# Variable usage = 100.00%
# ----------Iter = 6228----------
# Loss = 0.029338
# Variable usage = 100.00%
# ----------Iter = 6401----------
# Loss = 0.028926
# Variable usage = 100.00%
# ----------Iter = 6574----------
# Loss = 0.028540
# Variable usage = 100.00%
# ----------Iter = 6747----------
# Loss = 0.028180
# Variable usage = 100.00%
# ----------Iter = 6920----------
# Loss = 0.027841
# Variable usage = 100.00%
# ----------Iter = 7093----------
# Loss = 0.027526
# Variable usage = 100.00%
# ----------Iter = 7266----------
# Loss = 0.027235
# Variable usage = 100.00%
# ----------Iter = 7439----------
# Loss = 0.026965
# Variable usage = 100.00%
# ----------Iter = 7612----------
# Loss = 0.026716
# Variable usage = 99.17%
# ----------Iter = 7785----------
# Loss = 0.026489
# Variable usage = 99.17%
# ----------Iter = 7958----------
# Loss = 0.026279
# Variable usage = 99.17%
# ----------Iter = 8131----------
# Loss = 0.026088
# Variable usage = 99.17%
# ----------Iter = 8304----------
# Loss = 0.025914
# Variable usage = 98.89%
# ----------Iter = 8477----------
# Loss = 0.025752
# Variable usage = 98.34%
# ----------Iter = 8650----------
# Loss = 0.025604
# Variable usage = 97.51%
# ----------Iter = 8823----------
# Loss = 0.025469
# Variable usage = 95.84%
# ----------Iter = 8996----------
# Loss = 0.025346
# Variable usage = 95.01%
# ----------Iter = 9169----------
# Loss = 0.025233
# Variable usage = 93.63%
# ----------Iter = 9342----------
# Loss = 0.025128
# Variable usage = 92.24%
# ----------Iter = 9515----------
# Loss = 0.025031
# Variable usage = 90.86%
# ----------Iter = 9688----------
# Loss = 0.024938
# Variable usage = 90.30%
# ----------Iter = 9861----------
# Loss = 0.024850
# Variable usage = 89.47%
# ----------Iter = 10034----------
# Loss = 0.024765
# Variable usage = 88.09%
# ----------Iter = 10207----------
# Loss = 0.024686
# Variable usage = 86.15%
# ----------Iter = 10380----------
# Loss = 0.024608
# Variable usage = 84.76%
# ----------Iter = 10553----------
# Loss = 0.024531
# Variable usage = 84.21%
# ----------Iter = 10726----------
# Loss = 0.024459
# Variable usage = 83.93%
# ----------Iter = 10899----------
# Loss = 0.024389
# Variable usage = 81.72%
# ----------Iter = 11072----------
# Loss = 0.024323
# Variable usage = 80.33%
# ----------Iter = 11245----------
# Loss = 0.024260
# Variable usage = 78.67%
# ----------Iter = 11418----------
# Loss = 0.024199
# Variable usage = 78.39%
# ----------Iter = 11591----------
# Loss = 0.024138
# Variable usage = 78.12%
# ----------Iter = 11764----------
# Loss = 0.024080
# Variable usage = 77.29%
# ----------Iter = 11937----------
# Loss = 0.024024
# Variable usage = 77.29%
# ----------Iter = 12110----------
# Loss = 0.023969
# Variable usage = 76.45%
# ----------Iter = 12283----------
# Loss = 0.023917
# Variable usage = 75.62%
# ----------Iter = 12456----------
# Loss = 0.023866
# Variable usage = 74.52%
# ----------Iter = 12629----------
# Loss = 0.023815
# Variable usage = 73.41%
# ----------Iter = 12802----------
# Loss = 0.023766
# Variable usage = 72.58%
# ----------Iter = 12975----------
# Loss = 0.023718
# Variable usage = 71.75%
# ----------Iter = 13148----------
# Loss = 0.023671
# Variable usage = 69.53%
# ----------Iter = 13321----------
# Loss = 0.023625
# Variable usage = 69.25%
# ----------Iter = 13494----------
# Loss = 0.023581
# Variable usage = 68.70%
# ----------Iter = 13667----------
# Loss = 0.023537
# Variable usage = 68.98%
# ----------Iter = 13840----------
# Loss = 0.023494
# Variable usage = 68.14%
# ----------Iter = 14013----------
# Loss = 0.023453
# Variable usage = 67.59%
# ----------Iter = 14186----------
# Loss = 0.023412
# Variable usage = 66.48%
# ----------Iter = 14359----------
# Loss = 0.023372
# Variable usage = 65.93%
# ----------Iter = 14532----------
# Loss = 0.023333
# Variable usage = 64.82%
# ----------Iter = 14705----------
# Loss = 0.023297
# Variable usage = 64.54%
# ----------Iter = 14878----------
# Loss = 0.023259
# Variable usage = 64.54%
# ----------Iter = 15051----------
# Loss = 0.023223
# Variable usage = 64.27%
# ----------Iter = 15224----------
# Loss = 0.023188
# Variable usage = 64.27%
# ----------Iter = 15397----------
# Loss = 0.023154
# Variable usage = 63.71%
# ----------Iter = 15570----------
# Loss = 0.023121
# Variable usage = 63.16%
# ----------Iter = 15743----------
# Loss = 0.023089
# Variable usage = 63.16%
# ----------Iter = 15916----------
# Loss = 0.023059
# Variable usage = 62.88%
# ----------Iter = 16089----------
# Loss = 0.023029
# Variable usage = 62.60%
# ----------Iter = 16262----------
# Loss = 0.023000
# Variable usage = 62.60%
# ----------Iter = 16435----------
# Loss = 0.022969
# Variable usage = 61.77%
# ----------Iter = 16608----------
# Loss = 0.022938
# Variable usage = 61.22%
# ----------Iter = 16781----------
# Loss = 0.022908
# Variable usage = 60.11%
# ----------Iter = 16954----------
# Loss = 0.022879
# Variable usage = 59.83%
# ----------Iter = 17127----------
# Loss = 0.022852
# Variable usage = 59.56%
# ----------Iter = 17300----------
# Loss = 0.022824
# Variable usage = 59.28%
# ----------Iter = 17473----------
# Loss = 0.022798
# Variable usage = 57.89%
# ----------Iter = 17646----------
# Loss = 0.022771
# Variable usage = 57.62%
# ----------Iter = 17819----------
# Loss = 0.022745
# Variable usage = 57.06%
# ----------Iter = 17992----------
# Loss = 0.022719
# Variable usage = 56.79%
# ----------Iter = 18165----------
# Loss = 0.022694
# Variable usage = 56.79%
# ----------Iter = 18338----------
# Loss = 0.022669
# Variable usage = 56.51%
# ----------Iter = 18511----------
# Loss = 0.022645
# Variable usage = 56.51%
# ----------Iter = 18684----------
# Loss = 0.022623
# Variable usage = 55.96%
# ----------Iter = 18857----------
# Loss = 0.022601
# Variable usage = 55.96%
# ----------Iter = 19030----------
# Loss = 0.022579
# Variable usage = 56.23%
# ----------Iter = 19203----------
# Loss = 0.022559
# Variable usage = 55.96%
# ----------Iter = 19376----------
# Loss = 0.022538
# Variable usage = 55.40%
# ----------Iter = 19549----------
# Loss = 0.022518
# Variable usage = 55.40%
# ----------Iter = 19722----------
# Loss = 0.022499
# Variable usage = 55.68%
# ----------Iter = 19895----------
# Loss = 0.022479
# Variable usage = 55.96%
# ----------Iter = 20068----------
# Loss = 0.022461
# Variable usage = 55.96%
# ----------Iter = 20241----------
# Loss = 0.022442
# Variable usage = 55.68%
# ----------Iter = 20414----------
# Loss = 0.022424
# Variable usage = 55.40%
# ----------Iter = 20587----------
# Loss = 0.022405
# Variable usage = 55.40%
# ----------Iter = 20760----------
# Loss = 0.022388
# Variable usage = 55.40%
# ----------Iter = 20933----------
# Loss = 0.022370
# Variable usage = 55.12%
# ----------Iter = 21106----------
# Loss = 0.022353
# Variable usage = 54.85%
# ----------Iter = 21279----------
# Loss = 0.022336
# Variable usage = 54.57%
# ----------Iter = 21452----------
# Loss = 0.022319
# Variable usage = 54.57%
# ----------Iter = 21625----------
# Loss = 0.022303
# Variable usage = 54.29%
# ----------Iter = 21798----------
# Loss = 0.022287
# Variable usage = 54.02%
# ----------Iter = 21971----------
# Loss = 0.022272
# Variable usage = 54.02%
# ----------Iter = 22144----------
# Loss = 0.022257
# Variable usage = 54.02%
# ----------Iter = 22317----------
# Loss = 0.022242
# Variable usage = 54.57%

# %%
# Loss function plot
plt.figure(figsize=(8, 5))
plt.plot(50 * np.arange(len(train_loss_list)), train_loss_list)
plt.title('cMLP training')
plt.ylabel('Loss')
plt.xlabel('Training steps')
plt.tight_layout()
plt.show()

# %%
GC_est = cmlp.GC().cpu().data.numpy()

print('Estimated variable usage = %.2f%%' % (100 * np.mean(GC_est)))


# Make figures
fig, axarr = plt.subplots(1, 1, figsize=(16, 5))
axarr.imshow(GC_est, cmap='Blues')
axarr.set_title('GC estimated')
axarr.set_ylabel('Affected series')
axarr.set_xlabel('Causal series')
axarr.set_xticks([])
axarr.set_yticks([])

# %%
GC_est

# %%
# Human-readable names for the series
series_names = [
    'TTF Gas Futures', 'Natural Gas (NA)', 'Bayer Stock', 'Volkswagen Stock',
    'DAX Index', 'Cheniere Energy', 'Shell Stock', 'EUR/USD Exchange Rate',
    'RUB/EUR Exchange Rate', 'Reliance Stock', 
    'Brent Crude Oil', 'Coal Prices', 'BP Stock', 
    'TotalEnergies Stock', 'E.ON Stock', 'RWE Stock', 'BASF Stock', 
    'Siemens Stock', 'Vestas Wind Systems Stock'
]

# Plotting
fig, ax = plt.subplots(figsize=(10, 10))

# Plot the matrix
cax = ax.imshow(GC_est, cmap='Blues', aspect='auto')

# Set title and axis labels
ax.set_title('Granger Causality Estimation', fontsize=16)
ax.set_xlabel('Causal Series (X-axis)', fontsize=14)
ax.set_ylabel('Affected Series (Y-axis)', fontsize=14)

# Set ticks and labels
ax.set_xticks(np.arange(len(series_names)))
ax.set_yticks(np.arange(len(series_names)))

ax.set_xticklabels(series_names, fontsize=12, rotation=45, ha='right')
ax.set_yticklabels(series_names, fontsize=12)


# Add gridlines based on the minor ticks
ax.grid(which='minor', color='w', linestyle='-', linewidth=2)
ax.set_xticks(np.arange(-0.5, len(series_names), 1), minor=True)
ax.set_yticks(np.arange(-0.5, len(series_names), 1), minor=True)
ax.grid(which='minor', color='gray', linestyle='-', linewidth=0.5)

plt.tight_layout()
plt.savefig('granger_causality_estimation.png', dpi=300, bbox_inches='tight',  facecolor='white')
plt.show()

# %%
import networkx as nx

# %%
# Create a directed graph
G = nx.DiGraph()

# Add nodes
for idx, name in enumerate(series_names):
    G.add_node(idx, label=name)

# Add edges based on GC_est matrix
for x in range(GC_est.shape[0]):
    for y in range(GC_est.shape[1]):
        if GC_est[x, y] == 1:
            G.add_edge(y, x)

# Define position for nodes
pos = nx.shell_layout(G)  # You can change the layout if needed

# Draw the graph
plt.figure(figsize=(12, 10))
nx.draw(G, pos, with_labels=True, node_size=3000, node_color='lightblue', arrowsize=20, font_size=10,
        labels=nx.get_node_attributes(G, 'label'))

plt.title('Granger Causality Graph', fontsize=16)
plt.savefig('granger_causality_est_graph.png', dpi=300, bbox_inches='tight',  facecolor='white')
plt.show()
